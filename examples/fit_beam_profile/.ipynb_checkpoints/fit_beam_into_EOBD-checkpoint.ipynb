# %%
import pylab as pl
import pjflab
% matplotlib inline

# %%
data= pl.array([[0, 600, 655],
[1, 570, 612],
[2, 572, 635],
[3, 563, 620],
[4, 572, 615],
[5, 573, 650],
[6, 592, 682],
[8, 610, 673],
[10, 683, 735],
[12, 755, 872],
[14, 906, 901],
[16, 989, 953],
[18, 1045, 1062],
[20, 1220, 1135],
[22, 1368, 1362],
[26, 1616, 1534]])

lam=1064e-9
um=1e6

pos = data[:,0 ]*0.0254
wx = data[:,1]*0.5*1e-6
wy = data[:,2]*0.5*1e-6

w0xguess = 300e-6
z0xguess= 0.1

w0yguess = 300e-6
z0yguess= 0.1

w0x, z0x = fit_beam_size.fit_beam_size(pos, wx, w0xguess, z0xguess, lam, 1, 100, 'Beam scan fit x-axis', True, True, 'xaxis_fit.pdf')
w0y, z0y = fit_beam_size.fit_beam_size(pos, wy, w0xguess, z0xguess, lam, 1, 100, 'Beam scan fit y-axis', True, True, 'yaxis_fit.pdf')

# %%
3.7/0.623
# Out:
# 5.9390048154093105
